# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %%
#Create a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 780

# %%
##Perform API call

#Import dependencies
import requests
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | kahului
# Processing Record 3 of Set 1 | klaksvik
# Processing Record 4 of Set 1 | vuktyl
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | hilo
# Processing Record 7 of Set 1 | san cristobal
# Processing Record 8 of Set 1 | vila franca do campo
# Processing Record 9 of Set 1 | ust-tsilma
# Processing Record 10 of Set 1 | thaton
# Processing Record 11 of Set 1 | lagoa
# Processing Record 12 of Set 1 | ribeira grande
# Processing Record 13 of Set 1 | cape town
# Processing Record 14 of Set 1 | skibbereen
# Processing Record 15 of Set 1 | itarema
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | bluff
# Processing Record 18 of Set 1 | atuona
# Processing Record 19 of Set 1 | barrow
# Processing Record 20 of Set 1 | port elizabeth
# Processing Record 21 of Set 1 | longyearbyen
# Processing Record 22 of Set 1 | tessalit
# Processing Record 23 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 1 | cabo san lucas
# Processing Record 25 of Set 1 | bilibino
# Processing Record 26 of Set 1 | vaini
# Processing Record 27 of Set 1 | ano mera
# Processing Record 28 of Set 1 | katsuura
# Processing Record 29 of Set 1 | nome
# Processing Record 30 of Set 1 | butaritari
# Processing Record 31 of Set 1 | aracaju
# Processing Record 32 of Set 1 | inhambane
# Processing Record 33 of Set 1 | bredasdorp
# Processing Record 34 of Set 1 | asau
# Processing Record 35 of Set 1 | touros
# Processing Record 36 of Set 1 | ancud
# Processing Record 37 of Set 1 | skegness
# Processing Record 38 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 1 | thompson
# Processing Record 40 of Set 1 | araouane
# Processing Record 41 of Set 1 | dikson
# Processing Record 42 of Set 1 | saint-philippe
# Processing Record 43 of Set 1 | paradwip
# City not found. Skipping...
# Processing Record 44 of Set 1 | husavik
# Processing Record 45 of Set 1 | almaznyy
# Processing Record 46 of Set 1 | moerai
# Processing Record 47 of Set 1 | hermanus
# Processing Record 48 of Set 1 | smolenka
# Processing Record 49 of Set 1 | san fernando
# Processing Record 50 of Set 1 | jamestown
# Processing Record 1 of Set 2 | fallon
# Processing Record 2 of Set 2 | hobart
# Processing Record 3 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 4 of Set 2 | arraial do cabo
# Processing Record 5 of Set 2 | puerto ayora
# Processing Record 6 of Set 2 | tateyama
# Processing Record 7 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 2 | gao
# Processing Record 9 of Set 2 | dhidhdhoo
# Processing Record 10 of Set 2 | tuatapere
# Processing Record 11 of Set 2 | east london
# Processing Record 12 of Set 2 | rikitea
# Processing Record 13 of Set 2 | caala
# Processing Record 14 of Set 2 | villa sandino
# Processing Record 15 of Set 2 | stromness
# Processing Record 16 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 2 | lebu
# Processing Record 18 of Set 2 | maragogi
# Processing Record 19 of Set 2 | bethel
# Processing Record 20 of Set 2 | berlevag
# Processing Record 21 of Set 2 | rudnogorsk
# Processing Record 22 of Set 2 | ulladulla
# Processing Record 23 of Set 2 | hithadhoo
# Processing Record 24 of Set 2 | panaba
# Processing Record 25 of Set 2 | port macquarie
# Processing Record 26 of Set 2 | colorado springs
# Processing Record 27 of Set 2 | rindal
# Processing Record 28 of Set 2 | belyy yar
# Processing Record 29 of Set 2 | verkhnyaya toyma
# Processing Record 30 of Set 2 | pacific grove
# Processing Record 31 of Set 2 | mar del plata
# Processing Record 32 of Set 2 | torbay
# Processing Record 33 of Set 2 | cap malheureux
# Processing Record 34 of Set 2 | bathsheba
# Processing Record 35 of Set 2 | lasa
# Processing Record 36 of Set 2 | kalugumalai
# Processing Record 37 of Set 2 | vanavara
# Processing Record 38 of Set 2 | san patricio
# Processing Record 39 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 40 of Set 2 | moron
# Processing Record 41 of Set 2 | hobyo
# Processing Record 42 of Set 2 | port hedland
# Processing Record 43 of Set 2 | botucatu
# Processing Record 44 of Set 2 | iqaluit
# Processing Record 45 of Set 2 | bubaque
# Processing Record 46 of Set 2 | mataura
# Processing Record 47 of Set 2 | kushiro
# Processing Record 48 of Set 2 | busselton
# Processing Record 49 of Set 2 | taburi
# City not found. Skipping...
# Processing Record 50 of Set 2 | nikolskoye
# Processing Record 1 of Set 3 | bambous virieux
# Processing Record 2 of Set 3 | yellowknife
# Processing Record 3 of Set 3 | qaanaaq
# Processing Record 4 of Set 3 | carnarvon
# Processing Record 5 of Set 3 | yaan
# Processing Record 6 of Set 3 | buraydah
# Processing Record 7 of Set 3 | ostrovnoy
# Processing Record 8 of Set 3 | atar
# Processing Record 9 of Set 3 | kapaa
# Processing Record 10 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 3 | tuktoyaktuk
# Processing Record 12 of Set 3 | wajima
# Processing Record 13 of Set 3 | avera
# Processing Record 14 of Set 3 | korla
# Processing Record 15 of Set 3 | avarua
# Processing Record 16 of Set 3 | berdigestyakh
# Processing Record 17 of Set 3 | port alfred
# Processing Record 18 of Set 3 | comodoro rivadavia
# Processing Record 19 of Set 3 | przasnysz
# Processing Record 20 of Set 3 | varzea da palma
# Processing Record 21 of Set 3 | batagay-alyta
# Processing Record 22 of Set 3 | vanimo
# Processing Record 23 of Set 3 | general roca
# Processing Record 24 of Set 3 | half moon bay
# Processing Record 25 of Set 3 | padang
# Processing Record 26 of Set 3 | kilindoni
# Processing Record 27 of Set 3 | beringovskiy
# Processing Record 28 of Set 3 | bastia
# Processing Record 29 of Set 3 | mwene-ditu
# Processing Record 30 of Set 3 | coihaique
# Processing Record 31 of Set 3 | wanaka
# Processing Record 32 of Set 3 | vao
# Processing Record 33 of Set 3 | palauig
# Processing Record 34 of Set 3 | coquimbo
# Processing Record 35 of Set 3 | teknaf
# Processing Record 36 of Set 3 | guanica
# Processing Record 37 of Set 3 | norman wells
# Processing Record 38 of Set 3 | kavieng
# Processing Record 39 of Set 3 | coxim
# Processing Record 40 of Set 3 | northam
# Processing Record 41 of Set 3 | haibowan
# City not found. Skipping...
# Processing Record 42 of Set 3 | mao
# Processing Record 43 of Set 3 | cassilandia
# Processing Record 44 of Set 3 | luang prabang
# Processing Record 45 of Set 3 | guerrero negro
# Processing Record 46 of Set 3 | mexticacan
# Processing Record 47 of Set 3 | ambodifototra
# City not found. Skipping...
# Processing Record 48 of Set 3 | leningradskiy
# Processing Record 49 of Set 3 | benavente
# Processing Record 50 of Set 3 | georgetown
# Processing Record 1 of Set 4 | baghdad
# Processing Record 2 of Set 4 | pevek
# Processing Record 3 of Set 4 | mazyr
# Processing Record 4 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 5 of Set 4 | provideniya
# Processing Record 6 of Set 4 | asosa
# Processing Record 7 of Set 4 | skerries
# Processing Record 8 of Set 4 | mitsamiouli
# Processing Record 9 of Set 4 | cherskiy
# Processing Record 10 of Set 4 | tasiilaq
# Processing Record 11 of Set 4 | gushikawa
# Processing Record 12 of Set 4 | kayerkan
# Processing Record 13 of Set 4 | bowen
# Processing Record 14 of Set 4 | neuquen
# Processing Record 15 of Set 4 | olafsvik
# Processing Record 16 of Set 4 | hoquiam
# Processing Record 17 of Set 4 | chuy
# Processing Record 18 of Set 4 | puerto carreno
# Processing Record 19 of Set 4 | mount gambier
# Processing Record 20 of Set 4 | kruisfontein
# Processing Record 21 of Set 4 | venafro
# Processing Record 22 of Set 4 | seryshevo
# Processing Record 23 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 24 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 25 of Set 4 | marsh harbour
# Processing Record 26 of Set 4 | dese
# Processing Record 27 of Set 4 | mahebourg
# Processing Record 28 of Set 4 | henties bay
# Processing Record 29 of Set 4 | saint-leu
# Processing Record 30 of Set 4 | zapolyarnyy
# Processing Record 31 of Set 4 | new norfolk
# Processing Record 32 of Set 4 | kaeo
# Processing Record 33 of Set 4 | belfast
# Processing Record 34 of Set 4 | eenhana
# Processing Record 35 of Set 4 | steamboat springs
# Processing Record 36 of Set 4 | laguna
# Processing Record 37 of Set 4 | grosseto
# Processing Record 38 of Set 4 | high level
# Processing Record 39 of Set 4 | aklavik
# Processing Record 40 of Set 4 | tarija
# Processing Record 41 of Set 4 | laiwu
# Processing Record 42 of Set 4 | ous
# Processing Record 43 of Set 4 | oksfjord
# Processing Record 44 of Set 4 | dong xoai
# Processing Record 45 of Set 4 | chokurdakh
# Processing Record 46 of Set 4 | karakose
# City not found. Skipping...
# Processing Record 47 of Set 4 | juneau
# Processing Record 48 of Set 4 | khatanga
# Processing Record 49 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 50 of Set 4 | riyadh
# Processing Record 1 of Set 5 | constitucion
# Processing Record 2 of Set 5 | clyde river
# Processing Record 3 of Set 5 | port blair
# Processing Record 4 of Set 5 | nabire
# Processing Record 5 of Set 5 | tubruq
# City not found. Skipping...
# Processing Record 6 of Set 5 | castro
# Processing Record 7 of Set 5 | pochutla
# Processing Record 8 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 5 | tungkang
# City not found. Skipping...
# Processing Record 10 of Set 5 | moranbah
# Processing Record 11 of Set 5 | upernavik
# Processing Record 12 of Set 5 | bengkulu
# Processing Record 13 of Set 5 | mbekenyera
# Processing Record 14 of Set 5 | pritzwalk
# Processing Record 15 of Set 5 | cidreira
# Processing Record 16 of Set 5 | tiarei
# Processing Record 17 of Set 5 | victor harbor
# Processing Record 18 of Set 5 | tomatlan
# Processing Record 19 of Set 5 | sarangani
# Processing Record 20 of Set 5 | stupava
# Processing Record 21 of Set 5 | cayenne
# Processing Record 22 of Set 5 | camacha
# Processing Record 23 of Set 5 | takoradi
# Processing Record 24 of Set 5 | san luis
# Processing Record 25 of Set 5 | griffith
# Processing Record 26 of Set 5 | sao filipe
# Processing Record 27 of Set 5 | namatanai
# Processing Record 28 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 5 | svetlyy
# Processing Record 30 of Set 5 | chase
# Processing Record 31 of Set 5 | sept-iles
# Processing Record 32 of Set 5 | awjilah
# Processing Record 33 of Set 5 | pisco
# Processing Record 34 of Set 5 | kazerun
# Processing Record 35 of Set 5 | roura
# Processing Record 36 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 5 | marzuq
# Processing Record 38 of Set 5 | launceston
# Processing Record 39 of Set 5 | pionerskiy
# Processing Record 40 of Set 5 | hasaki
# Processing Record 41 of Set 5 | ewa beach
# Processing Record 42 of Set 5 | vilyuysk
# Processing Record 43 of Set 5 | port lincoln
# Processing Record 44 of Set 5 | muroto
# Processing Record 45 of Set 5 | lorengau
# Processing Record 46 of Set 5 | paraiso
# Processing Record 47 of Set 5 | starachowice
# Processing Record 48 of Set 5 | kashi
# Processing Record 49 of Set 5 | necochea
# Processing Record 50 of Set 5 | te anau
# Processing Record 1 of Set 6 | wattegama
# Processing Record 2 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 6 | narsaq
# Processing Record 4 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 5 of Set 6 | tiksi
# Processing Record 6 of Set 6 | beneditinos
# Processing Record 7 of Set 6 | palmer
# Processing Record 8 of Set 6 | san carlos del zulia
# Processing Record 9 of Set 6 | iquique
# Processing Record 10 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 11 of Set 6 | barreirinhas
# Processing Record 12 of Set 6 | plettenberg bay
# Processing Record 13 of Set 6 | sinnamary
# Processing Record 14 of Set 6 | richards bay
# Processing Record 15 of Set 6 | zhirnovsk
# Processing Record 16 of Set 6 | gat
# Processing Record 17 of Set 6 | akhmim
# Processing Record 18 of Set 6 | doha
# Processing Record 19 of Set 6 | morant bay
# Processing Record 20 of Set 6 | kudahuvadhoo
# Processing Record 21 of Set 6 | shintomi
# Processing Record 22 of Set 6 | severo-kurilsk
# Processing Record 23 of Set 6 | cocobeach
# Processing Record 24 of Set 6 | saint-denis
# Processing Record 25 of Set 6 | port moresby
# Processing Record 26 of Set 6 | kodiak
# Processing Record 27 of Set 6 | kuryk
# Processing Record 28 of Set 6 | sydney
# Processing Record 29 of Set 6 | broome
# Processing Record 30 of Set 6 | batemans bay
# Processing Record 31 of Set 6 | grand gaube
# Processing Record 32 of Set 6 | hvide sande
# Processing Record 33 of Set 6 | san juan
# Processing Record 34 of Set 6 | torres
# Processing Record 35 of Set 6 | camana
# Processing Record 36 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 37 of Set 6 | nanortalik
# Processing Record 38 of Set 6 | xai-xai
# Processing Record 39 of Set 6 | tanout
# Processing Record 40 of Set 6 | yatou
# Processing Record 41 of Set 6 | skagastrond
# City not found. Skipping...
# Processing Record 42 of Set 6 | ilulissat
# Processing Record 43 of Set 6 | las palmas
# Processing Record 44 of Set 6 | cedarburg
# Processing Record 45 of Set 6 | abha
# Processing Record 46 of Set 6 | concepcion
# Processing Record 47 of Set 6 | teguldet
# Processing Record 48 of Set 6 | quepos
# Processing Record 49 of Set 6 | port victoria
# Processing Record 50 of Set 6 | houma
# Processing Record 1 of Set 7 | staryy nadym
# Processing Record 2 of Set 7 | vardo
# Processing Record 3 of Set 7 | aitape
# Processing Record 4 of Set 7 | saldanha
# Processing Record 5 of Set 7 | mercedes
# Processing Record 6 of Set 7 | jardim
# Processing Record 7 of Set 7 | saskylakh
# Processing Record 8 of Set 7 | muyinga
# Processing Record 9 of Set 7 | xichang
# Processing Record 10 of Set 7 | russell
# Processing Record 11 of Set 7 | kiruna
# Processing Record 12 of Set 7 | ugoofaaru
# Processing Record 13 of Set 7 | hetauda
# Processing Record 14 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 15 of Set 7 | simiti
# Processing Record 16 of Set 7 | barsovo
# Processing Record 17 of Set 7 | yago
# Processing Record 18 of Set 7 | codrington
# Processing Record 19 of Set 7 | ostersund
# Processing Record 20 of Set 7 | barguzin
# Processing Record 21 of Set 7 | cervo
# Processing Record 22 of Set 7 | batticaloa
# Processing Record 23 of Set 7 | pueblo bello
# Processing Record 24 of Set 7 | santa cruz cabralia
# Processing Record 25 of Set 7 | pandan
# Processing Record 26 of Set 7 | isangel
# Processing Record 27 of Set 7 | sitka
# Processing Record 28 of Set 7 | mount isa
# Processing Record 29 of Set 7 | casino
# Processing Record 30 of Set 7 | poum
# Processing Record 31 of Set 7 | tecoanapa
# Processing Record 32 of Set 7 | moche
# Processing Record 33 of Set 7 | east lansing
# Processing Record 34 of Set 7 | ixtapa
# Processing Record 35 of Set 7 | flinders
# Processing Record 36 of Set 7 | centralia
# Processing Record 37 of Set 7 | smoljan
# Processing Record 38 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 39 of Set 7 | faanui
# Processing Record 40 of Set 7 | denpasar
# Processing Record 41 of Set 7 | yumen
# Processing Record 42 of Set 7 | trinidad
# Processing Record 43 of Set 7 | paragominas
# Processing Record 44 of Set 7 | okato
# Processing Record 45 of Set 7 | mgachi
# Processing Record 46 of Set 7 | darnah
# Processing Record 47 of Set 7 | senador jose porfirio
# Processing Record 48 of Set 7 | isoka
# Processing Record 49 of Set 7 | havre-saint-pierre
# Processing Record 50 of Set 7 | outjo
# Processing Record 1 of Set 8 | mporokoso
# Processing Record 2 of Set 8 | axim
# Processing Record 3 of Set 8 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 4 of Set 8 | omboue
# Processing Record 5 of Set 8 | shimanovsk
# Processing Record 6 of Set 8 | pontal do parana
# Processing Record 7 of Set 8 | acarau
# Processing Record 8 of Set 8 | ponta do sol
# Processing Record 9 of Set 8 | yar-sale
# Processing Record 10 of Set 8 | agadez
# Processing Record 11 of Set 8 | yeppoon
# Processing Record 12 of Set 8 | rapid valley
# Processing Record 13 of Set 8 | mariental
# Processing Record 14 of Set 8 | syracuse
# Processing Record 15 of Set 8 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 8 | manokwari
# Processing Record 17 of Set 8 | odienne
# Processing Record 18 of Set 8 | harper
# Processing Record 19 of Set 8 | valleyview
# Processing Record 20 of Set 8 | adrar
# Processing Record 21 of Set 8 | caravelas
# Processing Record 22 of Set 8 | pinerovka
# Processing Record 23 of Set 8 | haines junction
# Processing Record 24 of Set 8 | bafoulabe
# Processing Record 25 of Set 8 | mabamba
# Processing Record 26 of Set 8 | havoysund
# Processing Record 27 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 8 | port hardy
# Processing Record 29 of Set 8 | lavrentiya
# Processing Record 30 of Set 8 | sokoni
# Processing Record 31 of Set 8 | khani
# Processing Record 32 of Set 8 | rio gallegos
# Processing Record 33 of Set 8 | taltal
# Processing Record 34 of Set 8 | vostok
# Processing Record 35 of Set 8 | mengcheng
# Processing Record 36 of Set 8 | aguie
# Processing Record 37 of Set 8 | norman
# Processing Record 38 of Set 8 | targusor
# Processing Record 39 of Set 8 | puerto leguizamo
# Processing Record 40 of Set 8 | san blas
# Processing Record 41 of Set 8 | monrovia
# Processing Record 42 of Set 8 | luderitz
# Processing Record 43 of Set 8 | peniche
# Processing Record 44 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 45 of Set 8 | la ronge
# Processing Record 46 of Set 8 | tezu
# Processing Record 47 of Set 8 | balaipungut
# Processing Record 48 of Set 8 | fairbanks
# Processing Record 49 of Set 8 | tagusao
# Processing Record 50 of Set 8 | muros
# Processing Record 1 of Set 9 | kaitangata
# Processing Record 2 of Set 9 | kopayhorod
# Processing Record 3 of Set 9 | bom jesus
# Processing Record 4 of Set 9 | nyurba
# Processing Record 5 of Set 9 | dehui
# Processing Record 6 of Set 9 | bilma
# Processing Record 7 of Set 9 | jalu
# Processing Record 8 of Set 9 | novyy urgal
# Processing Record 9 of Set 9 | mount pleasant
# Processing Record 10 of Set 9 | shakawe
# Processing Record 11 of Set 9 | san andres
# Processing Record 12 of Set 9 | khutar
# Processing Record 13 of Set 9 | losevo
# Processing Record 14 of Set 9 | kendari
# Processing Record 15 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 9 | bairiki
# Processing Record 17 of Set 9 | taiyuan
# Processing Record 18 of Set 9 | brae
# Processing Record 19 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 9 | snyder
# Processing Record 22 of Set 9 | lingao
# Processing Record 23 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 24 of Set 9 | mancora
# Processing Record 25 of Set 9 | puerto del rosario
# Processing Record 26 of Set 9 | camargo
# Processing Record 27 of Set 9 | labuhan
# Processing Record 28 of Set 9 | omsukchan
# Processing Record 29 of Set 9 | kjollefjord
# Processing Record 30 of Set 9 | antalaha
# Processing Record 31 of Set 9 | poltsamaa
# Processing Record 32 of Set 9 | hualmay
# Processing Record 33 of Set 9 | jasper
# Processing Record 34 of Set 9 | geraldton
# Processing Record 35 of Set 9 | emet
# Processing Record 36 of Set 9 | boende
# Processing Record 37 of Set 9 | siukh
# Processing Record 38 of Set 9 | ahipara
# Processing Record 39 of Set 9 | carutapera
# Processing Record 40 of Set 9 | maraa
# Processing Record 41 of Set 9 | uzhur
# Processing Record 42 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 9 | bachaquero
# Processing Record 44 of Set 9 | chegem
# Processing Record 45 of Set 9 | walvis bay
# Processing Record 46 of Set 9 | dongsheng
# Processing Record 47 of Set 9 | tarko-sale
# Processing Record 48 of Set 9 | oranjemund
# Processing Record 49 of Set 9 | ketchikan
# Processing Record 50 of Set 9 | tual
# Processing Record 1 of Set 10 | raga
# Processing Record 2 of Set 10 | victoria
# Processing Record 3 of Set 10 | derzhavinsk
# Processing Record 4 of Set 10 | waipawa
# Processing Record 5 of Set 10 | coruripe
# Processing Record 6 of Set 10 | hanzhong
# Processing Record 7 of Set 10 | ambon
# Processing Record 8 of Set 10 | sinjar
# Processing Record 9 of Set 10 | mandi
# Processing Record 10 of Set 10 | carberry
# Processing Record 11 of Set 10 | buala
# Processing Record 12 of Set 10 | pasni
# Processing Record 13 of Set 10 | lata
# Processing Record 14 of Set 10 | korostyshiv
# Processing Record 15 of Set 10 | zhigansk
# Processing Record 16 of Set 10 | tahe
# Processing Record 17 of Set 10 | los llanos de aridane
# Processing Record 18 of Set 10 | ornskoldsvik
# Processing Record 19 of Set 10 | okhotsk
# Processing Record 20 of Set 10 | stykkisholmur
# Processing Record 21 of Set 10 | bolu
# Processing Record 22 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 23 of Set 10 | godfrey
# Processing Record 24 of Set 10 | vallenar
# Processing Record 25 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 26 of Set 10 | juegang
# Processing Record 27 of Set 10 | ust-nera
# Processing Record 28 of Set 10 | pedernales
# Processing Record 29 of Set 10 | abu samrah
# Processing Record 30 of Set 10 | beidao
# Processing Record 31 of Set 10 | praia da vitoria
# Processing Record 32 of Set 10 | jieshi
# Processing Record 33 of Set 10 | khorixas
# Processing Record 34 of Set 10 | vila velha
# Processing Record 35 of Set 10 | umm kaddadah
# Processing Record 36 of Set 10 | champerico
# Processing Record 37 of Set 10 | reconquista
# Processing Record 38 of Set 10 | anloga
# Processing Record 39 of Set 10 | matagami
# Processing Record 40 of Set 10 | pierre
# Processing Record 41 of Set 10 | prince rupert
# Processing Record 42 of Set 10 | batagay
# Processing Record 43 of Set 10 | winnemucca
# Processing Record 44 of Set 10 | cody
# Processing Record 45 of Set 10 | sananduva
# Processing Record 46 of Set 10 | la baule-escoublac
# Processing Record 47 of Set 10 | luebo
# Processing Record 48 of Set 10 | narasannapeta
# Processing Record 49 of Set 10 | oussouye
# Processing Record 50 of Set 10 | anito
# Processing Record 1 of Set 11 | zeya
# Processing Record 2 of Set 11 | aksha
# Processing Record 3 of Set 11 | hendijan
# City not found. Skipping...
# Processing Record 4 of Set 11 | oranjestad
# Processing Record 5 of Set 11 | louis trichardt
# Processing Record 6 of Set 11 | viedma
# Processing Record 7 of Set 11 | sorong
# Processing Record 8 of Set 11 | shepsi
# Processing Record 9 of Set 11 | mbandaka
# Processing Record 10 of Set 11 | takaungu
# Processing Record 11 of Set 11 | shingu
# Processing Record 12 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 13 of Set 11 | santa cruz
# Processing Record 14 of Set 11 | saint george
# Processing Record 15 of Set 11 | maralal
# Processing Record 16 of Set 11 | ulaangom
# Processing Record 17 of Set 11 | srednekolymsk
# Processing Record 18 of Set 11 | lompoc
# Processing Record 19 of Set 11 | rawson
# Processing Record 20 of Set 11 | latur
# Processing Record 21 of Set 11 | tashtyp
# Processing Record 22 of Set 11 | muskegon
# Processing Record 23 of Set 11 | ayr
# Processing Record 24 of Set 11 | barmer
# Processing Record 25 of Set 11 | erzin
# Processing Record 26 of Set 11 | emerald
# Processing Record 27 of Set 11 | barabai
# Processing Record 28 of Set 11 | korgen
# Processing Record 29 of Set 11 | airai
# Processing Record 30 of Set 11 | cockburn town
# Processing Record 31 of Set 11 | spring valley
# Processing Record 32 of Set 11 | baherden
# Processing Record 33 of Set 11 | dunedin
# Processing Record 34 of Set 11 | mackay
# Processing Record 35 of Set 11 | portland
# Processing Record 36 of Set 11 | chadan
# Processing Record 37 of Set 11 | petropavl
# Processing Record 38 of Set 11 | sungai besar
# Processing Record 39 of Set 11 | tandil
# Processing Record 40 of Set 11 | guilin
# Processing Record 41 of Set 11 | garden city
# Processing Record 42 of Set 11 | porto belo
# Processing Record 43 of Set 11 | santa maria do suacui
# Processing Record 44 of Set 11 | kavaratti
# Processing Record 45 of Set 11 | pouembout
# Processing Record 46 of Set 11 | fortuna
# Processing Record 47 of Set 11 | bangui
# Processing Record 48 of Set 11 | talnakh
# Processing Record 49 of Set 11 | esperance
# Processing Record 50 of Set 11 | zemio
# Processing Record 1 of Set 12 | souillac
# Processing Record 2 of Set 12 | meulaboh
# Processing Record 3 of Set 12 | sao joao da barra
# Processing Record 4 of Set 12 | jacareacanga
# Processing Record 5 of Set 12 | armacao de pera
# Processing Record 6 of Set 12 | zhezkazgan
# Processing Record 7 of Set 12 | parainen
# Processing Record 8 of Set 12 | ponta delgada
# Processing Record 9 of Set 12 | sisimiut
# Processing Record 10 of Set 12 | taoudenni
# Processing Record 11 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 12 | shaoyang
# Processing Record 13 of Set 12 | umm lajj
# Processing Record 14 of Set 12 | ljaskovec
# City not found. Skipping...
# Processing Record 15 of Set 12 | abrau-dyurso
# Processing Record 16 of Set 12 | hot springs
# Processing Record 17 of Set 12 | hadsund
# Processing Record 18 of Set 12 | uusikaupunki
# Processing Record 19 of Set 12 | magadan
# Processing Record 20 of Set 12 | mastic beach
# Processing Record 21 of Set 12 | mehamn
# Processing Record 22 of Set 12 | solovetskiy
# City not found. Skipping...
# Processing Record 23 of Set 12 | lerwick
# Processing Record 24 of Set 12 | kupang
# Processing Record 25 of Set 12 | sola
# Processing Record 26 of Set 12 | zhangye
# Processing Record 27 of Set 12 | semey
# Processing Record 28 of Set 12 | borovoy
# Processing Record 29 of Set 12 | ignacio zaragoza
# Processing Record 30 of Set 12 | lazo
# Processing Record 31 of Set 12 | okitipupa
# Processing Record 32 of Set 12 | huarmey
# Processing Record 33 of Set 12 | jaen
# Processing Record 34 of Set 12 | poplar bluff
# Processing Record 35 of Set 12 | sabibah
# City not found. Skipping...
# Processing Record 36 of Set 12 | iralaya
# Processing Record 37 of Set 12 | alakurtti
# Processing Record 38 of Set 12 | nioro
# Processing Record 39 of Set 12 | san martin jilotepeque
# Processing Record 40 of Set 12 | salalah
# Processing Record 41 of Set 12 | ochakiv
# Processing Record 42 of Set 12 | kuruman
# Processing Record 43 of Set 12 | whitehorse
# Processing Record 44 of Set 12 | janakpur road
# City not found. Skipping...
# Processing Record 45 of Set 12 | ashibetsu
# Processing Record 46 of Set 12 | gorontalo
# Processing Record 47 of Set 12 | salsk
# Processing Record 48 of Set 12 | erenhot
# Processing Record 49 of Set 12 | sikonge
# Processing Record 50 of Set 12 | killybegs
# Processing Record 1 of Set 13 | matara
# Processing Record 2 of Set 13 | ponta pora
# Processing Record 3 of Set 13 | los altos
# Processing Record 4 of Set 13 | sangmelima
# Processing Record 5 of Set 13 | chaykovskaya
# Processing Record 6 of Set 13 | jennings
# Processing Record 7 of Set 13 | husum
# Processing Record 8 of Set 13 | eureka
# Processing Record 9 of Set 13 | westport
# Processing Record 10 of Set 13 | north bend
# Processing Record 11 of Set 13 | lasem
# Processing Record 12 of Set 13 | loubomo
# Processing Record 13 of Set 13 | baruun-urt
# Processing Record 14 of Set 13 | darhan
# Processing Record 15 of Set 13 | kenai
# Processing Record 16 of Set 13 | aswan
# Processing Record 17 of Set 13 | flin flon
# Processing Record 18 of Set 13 | tucuman
# Processing Record 19 of Set 13 | rocha
# Processing Record 20 of Set 13 | homer
# Processing Record 21 of Set 13 | victoria point
# Processing Record 22 of Set 13 | sar-e pul
# Processing Record 23 of Set 13 | beckley
# Processing Record 24 of Set 13 | hope
# Processing Record 25 of Set 13 | raton
# Processing Record 26 of Set 13 | kholm
# Processing Record 27 of Set 13 | sobolevo
# Processing Record 28 of Set 13 | chuguyevka
# Processing Record 29 of Set 13 | namibe
# Processing Record 30 of Set 13 | biltine
# Processing Record 31 of Set 13 | dandong
# Processing Record 32 of Set 13 | kyrksaeterora
# Processing Record 33 of Set 13 | bandar-e lengeh
# Processing Record 34 of Set 13 | ziro
# Processing Record 35 of Set 13 | fevralsk
# City not found. Skipping...
# Processing Record 36 of Set 13 | rabo de peixe
# Processing Record 37 of Set 13 | ahuimanu
# Processing Record 38 of Set 13 | poltavka
# Processing Record 39 of Set 13 | college
# Processing Record 40 of Set 13 | sandwick
# Processing Record 41 of Set 13 | sur
# Processing Record 42 of Set 13 | korb
# Processing Record 43 of Set 13 | roald
# Processing Record 44 of Set 13 | pasighat
# Processing Record 45 of Set 13 | pafos
# Processing Record 46 of Set 13 | tambo
# Processing Record 47 of Set 13 | mecca
# Processing Record 48 of Set 13 | hambantota
# Processing Record 49 of Set 13 | berbera
# Processing Record 50 of Set 13 | laela
# Processing Record 1 of Set 14 | samarai
# Processing Record 2 of Set 14 | powell
# Processing Record 3 of Set 14 | antofagasta
# Processing Record 4 of Set 14 | borogontsy
# Processing Record 5 of Set 14 | pangoa
# Processing Record 6 of Set 14 | edd
# Processing Record 7 of Set 14 | morro bay
# Processing Record 8 of Set 14 | libertador general san martin
# Processing Record 9 of Set 14 | caborca
# Processing Record 10 of Set 14 | harindanga
# Processing Record 11 of Set 14 | ouegoa
# Processing Record 12 of Set 14 | hervey bay
# Processing Record 13 of Set 14 | yakeshi
# Processing Record 14 of Set 14 | mana
# Processing Record 15 of Set 14 | aripuana
# Processing Record 16 of Set 14 | palau
# Processing Record 17 of Set 14 | manakara
# Processing Record 18 of Set 14 | zhangjiakou
# Processing Record 19 of Set 14 | willmar
# Processing Record 20 of Set 14 | batamshinskiy
# Processing Record 21 of Set 14 | oktyabrskiy
# Processing Record 22 of Set 14 | luocheng
# Processing Record 23 of Set 14 | auki
# Processing Record 24 of Set 14 | zhuhai
# Processing Record 25 of Set 14 | basoko
# Processing Record 26 of Set 14 | palu
# Processing Record 27 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 28 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 29 of Set 14 | manavalakurichi
# Processing Record 30 of Set 14 | pangnirtung
# Processing Record 31 of Set 14 | bandarbeyla
# Processing Record 32 of Set 14 | pareora
# Processing Record 33 of Set 14 | shestakovo
# Processing Record 34 of Set 14 | vieques
# Processing Record 35 of Set 14 | izumo
# Processing Record 36 of Set 14 | yurimaguas
# Processing Record 37 of Set 14 | misratah
# Processing Record 38 of Set 14 | yarmolyntsi
# Processing Record 39 of Set 14 | duz
# City not found. Skipping...
# Processing Record 40 of Set 14 | fort nelson
# Processing Record 41 of Set 14 | charters towers
# Processing Record 42 of Set 14 | jijiga
# Processing Record 43 of Set 14 | mattawa
# Processing Record 44 of Set 14 | kytlym
# City not found. Skipping...
# Processing Record 45 of Set 14 | yaviza
# Processing Record 46 of Set 14 | bull savanna
# Processing Record 47 of Set 14 | methoni
# Processing Record 48 of Set 14 | zhoucheng
# Processing Record 49 of Set 14 | eydhafushi
# Processing Record 50 of Set 14 | bac lieu
# Processing Record 1 of Set 15 | maningrida
# Processing Record 2 of Set 15 | mahajanga
# Processing Record 3 of Set 15 | qaqortoq
# Processing Record 4 of Set 15 | maumere
# Processing Record 5 of Set 15 | bykovo
# Processing Record 6 of Set 15 | kieta
# Processing Record 7 of Set 15 | tautira
# Processing Record 8 of Set 15 | kamaishi
# Processing Record 9 of Set 15 | soe
# Processing Record 10 of Set 15 | bemidji
# Processing Record 11 of Set 15 | clermont
# Processing Record 12 of Set 15 | kupino
# Processing Record 13 of Set 15 | scarborough
# Processing Record 14 of Set 15 | alyangula
# Processing Record 15 of Set 15 | itaueira
# Processing Record 16 of Set 15 | maceio
# Processing Record 17 of Set 15 | starkville
# Processing Record 18 of Set 15 | sinjah
# City not found. Skipping...
# Processing Record 19 of Set 15 | adelaide
# Processing Record 20 of Set 15 | ola
# Processing Record 21 of Set 15 | san pedro
# Processing Record 22 of Set 15 | tyret pervaya
# Processing Record 23 of Set 15 | romitan
# Processing Record 24 of Set 15 | nantucket
# Processing Record 25 of Set 15 | merauke
# Processing Record 26 of Set 15 | fairlie
# Processing Record 27 of Set 15 | boa vista
# Processing Record 28 of Set 15 | morros
# Processing Record 29 of Set 15 | noshiro
# Processing Record 30 of Set 15 | pavlodar
# Processing Record 31 of Set 15 | verkhoyansk
# Processing Record 32 of Set 15 | naze
# Processing Record 33 of Set 15 | kirundo
# Processing Record 34 of Set 15 | neiafu
# Processing Record 35 of Set 15 | ushtobe
# Processing Record 36 of Set 15 | san rafael
# Processing Record 37 of Set 15 | prainha
# Processing Record 38 of Set 15 | mancio lima
# Processing Record 39 of Set 15 | guaratinga
# Processing Record 40 of Set 15 | saint anthony
# Processing Record 41 of Set 15 | pimentel
# Processing Record 42 of Set 15 | tura
# Processing Record 43 of Set 15 | morondava
# Processing Record 44 of Set 15 | vilhena
# Processing Record 45 of Set 15 | jibuti
# Processing Record 46 of Set 15 | kaliua
# Processing Record 47 of Set 15 | mago
# Processing Record 48 of Set 15 | hay river
# Processing Record 49 of Set 15 | akyab
# Processing Record 50 of Set 15 | am timan
# Processing Record 1 of Set 16 | kapuskasing
# Processing Record 2 of Set 16 | ouesso
# Processing Record 3 of Set 16 | hun
# Processing Record 4 of Set 16 | ksenyevka
# City not found. Skipping...
# Processing Record 5 of Set 16 | moengo
# Processing Record 6 of Set 16 | micheweni
# Processing Record 7 of Set 16 | wadersloh
# Processing Record 8 of Set 16 | bontang
# Processing Record 9 of Set 16 | hamilton
# Processing Record 10 of Set 16 | khomeynishahr
# City not found. Skipping...
# Processing Record 11 of Set 16 | goderich
# Processing Record 12 of Set 16 | birobidzhan
# Processing Record 13 of Set 16 | sao jose da coroa grande
# Processing Record 14 of Set 16 | andros town
# Processing Record 15 of Set 16 | byron bay
# Processing Record 16 of Set 16 | ankazoabo
# Processing Record 17 of Set 16 | gawler
# Processing Record 18 of Set 16 | zonguldak
# Processing Record 19 of Set 16 | kingman
# Processing Record 20 of Set 16 | aksay
# Processing Record 21 of Set 16 | toliary
# City not found. Skipping...
# Processing Record 22 of Set 16 | iracoubo
# Processing Record 23 of Set 16 | kindu
# Processing Record 24 of Set 16 | evensk
# Processing Record 25 of Set 16 | fare
# Processing Record 26 of Set 16 | zlobin
# Processing Record 27 of Set 16 | sambava
# Processing Record 28 of Set 16 | boshnyakovo
# Processing Record 29 of Set 16 | skjervoy
# Processing Record 30 of Set 16 | nynashamn
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 725

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                    City Country      Lat       Lng  Max Temp  Humidity  \
# 0          Punta Arenas      CL -53.1500  -70.9167     55.51        50
# 1               Kahului      US  20.8947 -156.4700     74.84        90
# 2              Klaksvik      FO  62.2266   -6.5890     41.92        74
# 3                Vuktyl      RU  63.8567   57.3094      2.37        90
# 4                Albany      US  42.6001  -73.9662     32.95        84
# 5                  Hilo      US  19.7297 -155.0900     75.27        46
# 6         San Cristobal      VE   7.7669  -72.2250     71.78        44
# 7  Vila Franca Do Campo      PT  37.7167  -25.4333     65.19        63
# 8            Ust-Tsilma      RU  65.4410   52.1498      6.30        92
# 9                Thaton      MM  16.9206   97.3714     73.24        73
#
#    Cloudiness  Wind Speed Current Description
# 0           0       12.66           clear sky
# 1          40        4.61    scattered clouds
# 2         100       28.88     overcast clouds
# 3          79        3.47       broken clouds
# 4         100        1.99          light snow
# 5          90        4.61          light rain
# 6          85        5.64     overcast clouds
# 7          97        4.56     overcast clouds
# 8          94        4.72     overcast clouds
# 9           1        2.91           clear sky

# %%
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
